# %%
class Student:
    def __init__(self, name, lastname, gender, age, studentid, personid):
        self.name = name
        self.lastname = lastname
        self.gender = gender
        self.age = age
        self.studentid = studentid
        self.personid = personid

    if len(
    def setage(self, newAge):
        if self.__age < newAge:
            self.__age = newAge
        else: 
            print("อายุต้องมากกว่า")
            
    def showinfo(self):
        print("""
        name: {}
        lastname: {}
        gender: {}
        age: {}
        studentid: {}
        personid: {}
        """.format(self.name, self.lastname, self.gender, self.age, self.studentid, self.personid))

# %%
student_1 = Student ('ratanan', 'vasunan', 'male', 21, 6812732122, '1339900841846')

# %%
student_1.showinfo()
# Out:
#         name: ratanan
#         lastname: vasunan
#         gender: male
#         age: 21
#         studentid: 6812732122
#         personid: 1339900841846

# %%
student_1.setage(30)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 student_1.setage(30)
#
# Cell In[5], line 13, in Student.setage(self, newAge)
#      12 def setage(self, newAge):
# ---> 13     if self.__age < newAge:
#      14         self.__age = newAge
#      15     else:
#
# AttributeError: 'Student' object has no attribute '_Student__age'
