# %%
class Dog:
    def __init__(self, name, gender, gene, age, weight, color):
        self.name = name
        self.gender = gender
        self.gene = gene
        self.age = age
        self.weight = weight
        self.color = color

    def setAge(self, newAge):
        if newAge < self.__Age:
            print("eror")

    def showinfo(self):
        print("""
        name: {}
        gender: {}
        gene: {}
        age: {}
        weight: {}
        color: {}
        """.format(self.name, self.gender, self.gene, self.age, self.weight, self.color))

    def sit(self):
        print("Dog is sitting")

    def sleep(self):
        print("Dog is sleeping")

    def eat(self):
        print("Dog is eating")

# %%
dog_earn = Dog ('เอิน','female','golden', 20, 80,'gold')
dog_chol = Dog ('ชล', 'male', 'shivava', 20, 120, 'black')

# %%
dog_earn.showinfo()
# Out:
#         name: เอิน
#         gender: female
#         gene: golden
#         age: 20
#         weight: 80
#         color: gold

# %%
dog_chol.showinfo()
# Out:
#         name: ชล
#         gender: male
#         gene: shivava
#         age: 20
#         weight: 120
#         color: black

# %%
dog_chol.age=25

# %%
dog_chol.showinfo()
# Out:
#         name: ชล
#         gender: male
#         gene: shivava
#         age: 25
#         weight: 120
#         color: black

# %%
dog_chol.setAge(30)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 dog_chol.setAge(30)
#
# Cell In[68], line 11, in Dog.setAge(self, newAge)
#      10 def setAge(self, newAge):
# ---> 11     if newAge < self.__Age:
#      12         print("eror")
#
# AttributeError: 'Dog' object has no attribute '_Dog__Age'

# %%
dog_chol.showinfo()
# Out:
#         name: ชล
#         gender: male
#         gene: shivava
#         age: 25
#         weight: 120
#         color: black
